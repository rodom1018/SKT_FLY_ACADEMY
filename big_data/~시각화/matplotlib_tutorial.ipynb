# %%
import matplotlib.pylab as plt
# %matplotlib inline

plt.title("Plot")
plt.plot([1,4,9,16], [1,4,9,16], 'ro--')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)

# %%
plt.style.use('ggplot')
fig = plt.figure()
ax = fig.add_subplot(111)
data = [0,1]
ax.plot(data, 'rs--')
plt.show()

# %%
plt.style.use('ggplot')
fig = plt.figure()
ax = fig.add_subplot(111)

x = [0,2,4]
y1 = [0,4,2.5]
y2 = [2,0,1.5]

ax.plot(x, y1)
ax.plot(x,y2)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

csv = os.path.join('./samples/anime_stock_returns.csv')
df = pd.read_csv(csv)
df.head()
# Out:
#          Date  TOEI ANIMATION   IG Port
# 0  2015-01-01        1.000000  1.000000
# 1  2015-01-02        1.000000  1.000000
# 2  2015-01-05        1.011695  1.014082
# 3  2015-01-06        1.001463  1.000000
# 4  2015-01-07        0.982457  1.000824

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

csv = os.path.join('./samples/anime_stock_returns.csv')
df = pd.read_csv(csv, index_col =0, parse_dates=['Date'])
df.head()
"""
plt.style.use('ggplot')
flg = plt.figure(figsize=(10,4))
ax = fig.add_subplot(111)
ax.plot(df.index, df['TOEI ANIMATION'], label= 'TOEI ANIMATION')
ax.plot(df.index, df['IG Port'], label= 'IG Port')

plt.show()
"""
# Out:
# "\nplt.style.use('ggplot')\nflg = plt.figure(figsize=(10,4))\nax = fig.add_subplot(111)\nax.plot(df.index, df['TOEI ANIMATION'], label= 'TOEI ANIMATION')\nax.plot(df.index, df['IG Port'], label= 'IG Port')\n\nplt.show()\n"
