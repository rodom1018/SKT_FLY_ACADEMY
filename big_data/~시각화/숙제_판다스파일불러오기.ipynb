# %%
#csv, json , xlsx
import os
import pandas as pd

# %%
#csv (https://www.data.go.kr/data/15006331/fileData.do_
csv = os.path.join('./samples/game.csv')
#df = pd.read_csv(csv, encoding = 'CP949')
df = pd.read_csv(csv, encoding='CP949', index_col = 5)
df.head()
# Out:
#                       업종명         상호                      영업소소재지(도로명)  \
# 경도
# 128.574285  인터넷컴퓨터게임시설제공업    바글바글PC방      대구광역시 북구 구리로36길 6, 3층 (국우동)
# 128.596136  인터넷컴퓨터게임시설제공업  nu PC 산격점       대구광역시 북구 연암로 177, 2층 (산격동)
# 128.591230  인터넷컴퓨터게임시설제공업      헬로PC방  대구광역시 북구 침산로 162-15, 2,3층 (침산동)
# 128.585600  인터넷컴퓨터게임시설제공업      욜로PC방      대구광역시 북구 옥산로 94, 5층 (고성동3가)
# 128.555710  인터넷컴퓨터게임시설제공업        케이투       대구광역시 북구 구암로 135, 4층 (동천동)
#
#                              영업소소재지(지번)         위도      데이터기준일
# 경도
# 128.574285         대구광역시 북구 국우동 1118-1   35.947119  2021-07-14
# 128.596136   대구광역시 북구 산격동 750-3 (지상2층)   35.900225  2021-07-14
# 128.591230         대구광역시 북구 침산동 295-10   35.891077  2021-07-14
# 128.585600  대구광역시 북구 고성동3가 25-1 (지상5층)   35.884119  2021-07-14
# 128.555710     대구광역시 북구 동천동 878 (지상4층)   35.932099  2021-07-14

# %%
#json https://www.data.go.kr/data/15045417/fileData.do

csv = os.path.join('./samples/json_sample.json')
df = pd.read_json(csv)
df
# Out:
#               정책용어                                               생성배경  \
# 0    BRT(간선급행버스체계)  신도시 개발 등에 따른 통행 거리 증대와 수도권 주민의 교통난을 해 소하기 위해 도...
# 1         뿌리산업특화단지  뿌리산업 진흥과 첨단화에 관한 법률에 의하면 뿌리산업은 뿌리기술을 활용하여 사업을 ...
# 2             MZ세대                                               null
# 3        창조산업 클러스터  세계경제는 제조업 중심의 산업경제 시대를 지나 지식기반경제 시대에 접어들었으며 향후...
# 4         제주국제자유도시  제주국제자유도시는 기업활동에 최대한 편의를 제공하고 최적의 비즈니스 환경을 구축하여...
# ..             ...                                                ...
# 326      지역문제해결플랫폼                                               null
# 327       고령친화우수식품  소득증가와 의료기술발달 등으로 인간수명이 연장되면서 인구의 고령화가 가속화되었다. ...
# 328     선도마을관리협동조합  마을관리 사회적협동조합은 도시재생1)사업으로 조성된 거점시설 및 노후 주거지의 주택...
# 329       한국관광데이터랩                                               null
# 330  광역경제권 연계R&D사업  기존 RD 사업은 국가RD와 시·도 단위의 지역RD로 구분되어 추진되었으나 광역경제...
#
#                                                   용어설명  \
# 0                                                 null
# ...

# %%
# xlsx 

csv = os.path.join('./samples/excel_sample.xlsx')
df = pd.read_excel(csv, engine = "openpyxl")
df
# Out:
#                                                구분 예술인 산재보험* Unnamed: 2  \
# 0                                             NaN     가입유지자       신규가입
# 1                                            2017       683        166
# 2                                            2018       789        222
# 3                                            2019      2315       1682
# 4                                            2020      4365       2400
# 5                                            2021      6445       3409
# 6                                            2022      5307       1313
# 7  * 가입유지: 해당 연도 1일 이상 보험 가입유지자 (이전가입자, 신규가입자 포함)       NaN        NaN
# 8                          * 신규가입: 해당 연도 산재보험 가입자       NaN        NaN
# 9                  * 누적가입: '12. 11월부터 산재보험 가입자 총합       NaN        NaN
#
#   Unnamed: 3
# 0       누적가입
# 1       1331
# 2       1553
# 3       3235
# 4       5635
# 5       9044
# 6      10357
# 7        NaN
# 8        NaN
# 9        NaN
